# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import itertools
from itertools import product
import math
rng = np.random

# %%
# This will return an array representing N rolls of n dD
def dice_roll(n=1,D=6,N=1):
    return np.random.randint(1,D+1,(N,n))

# %%
# Roll N rolls of n dD sided dice, return their sums in the array values 
# and a dictionary that compiles how many times each sum appears, roll_dict
def sum_rolls(n=1,D=6,N=1,shift=0):
    roll_dict = {}
    rolls = dice_roll(n,D,N)
    values = np.sum(rolls,axis=1)+shift
    min_value = np.min(values)
    max_value = np.max(values)
    for i in range(min_value,max_value+1):
        roll_dict[i] = np.sum(values==i)
    return roll_dict,values

# %%
# Return counts of roll outcomes from N trials of rolling n dD and substracting the min
def subtract_min(n=4,D=6,N=100):
    roll_dict={}
    rolls = dice_roll(n,D,N)
    values = np.sum(rolls,axis=1)-np.min(rolls,axis=1)
    min_value = np.min(values)
    max_value = np.max(values)
    for i in range(min_value,max_value+1):
        roll_dict[i] = np.sum(values==i)
    return roll_dict,values

# %%
def numpy_stats(x):
    return np.array([[
        len(x),np.mean(x),np.std(x,ddof=1),np.min(x),np.quantile(x,0.25),np.median(x),np.percentile(x,75),np.max(x)
    ]])

# %%
# Creates a bar chart and box plot side by side using raw and compiled data.

# Collect/generate the data 
temp_dict,raw_values = sum_rolls(5,6,200)

# Initialize the figure
fig,axis = plt.subplots(1,2,figsize=(15,5),width_ratios=[5,3])

# Create bar chart using compiled data values
bars = axis[0].bar(temp_dict.keys(),temp_dict.values());
axis[0].bar_label(bars,fontsize=14)

# Create box plot using the raw values
axis[1].boxplot(raw_values,orientation="horizontal",tick_labels=[""],widths=0.5);
axis[0].set_xticks(range(0,31));
axis[1].set_xticks(range(0,31,2));

# Adjust the layout for the figure
fig.tight_layout()
# fig.savefig("../images/atribute_rolls_trial1.png",bbox_inches='tight',transparent=True);

# %%
# Creates a bar chart and box plot side by side using raw and compiled data.

# Collect/generate the data 
temp_dict,raw_values = sum_rolls(5,6,200,0)
temp_dict2,raw_values2 = sum_rolls(3,6,200,2)

# Initialize the figure
fig,axis = plt.subplots(1,2,figsize=(15,5),width_ratios=[5,3])

# Create bar chart using compiled data values
bars = axis[0].bar(temp_dict.keys(),temp_dict.values());
bars2 = axis[0].bar(temp_dict2.keys(),temp_dict2.values(),color="orange");
# axis[0].bar_label(bars,fontsize=14)
# axis[0].bar_label(bars2,fontsize=14)

# Create box plot using the raw values
axis[1].boxplot([raw_values,raw_values2],orientation="horizontal",tick_labels=["",""],widths=0.75);

# Format axes
axis[0].set_xticks(range(0,31));
axis[1].set_xticks(range(0,31,2));

# Adjust the layout for the figure
fig.tight_layout()
# fig.savefig("../images/opposed_roll_trial.png",bbox_inches='tight',transparent=True);

# %%
print(np.round(numpy_stats(raw_values),2).tolist())
print(np.round(numpy_stats(raw_values2),2).tolist())
# Out:
# [[200.0, 17.86, 4.22, 8.0, 15.0, 18.0, 21.0, 27.0]]
# [[200.0, 12.28, 3.09, 5.0, 10.0, 12.0, 14.0, 20.0]]

# %%
# Sample commands to create values from particular distributions
print(rng.normal(0,0.5,size=10))
print(rng.uniform(-5,5,10))
print(np.random.binomial(10, 1/3, 10))
print(sum(np.random.binomial(9, 0.1, 20000) == 0)/20000)
# Out:
# [-0.57654814  0.59872648 -0.42874034 -0.18893273  0.32532281 -0.21978592
#   0.28051183  0.91588379  0.40436262 -1.12436876]
# [ 3.40774237  3.52606942  3.26061663  1.479439    1.86717001  2.63627328
#   1.7963585   0.42566227 -3.66542617  3.09113836]
# [4 2 3 1 3 4 4 4 2 5]
# 0.38955

# %%
# Create table of test trials with 
# 90-110 participants
# averaging 75% positive tests
# averageing 25% false positives
# deviate the values by a normal distribution with mean 0 and stdev 0.5?
Trials = 10
Participants = rng.randint(90,110,Trials)
Positive_Tests = rng.binomial(Participants,0.75)
True_Positives = rng.binomial(Positive_Tests,0.75)
Percent_Correct = True_Positives/Positive_Tests*100
Compiled_Table = np.array([np.arange(1,11),Participants,Positive_Tests,True_Positives,Percent_Correct.astype(int)])
Compiled_Table.transpose()
# Out:
# array([[  1, 103,  79,  61,  77],
#        [  2,  98,  71,  59,  83],
#        [  3, 108,  83,  59,  71],
#        [  4, 101,  76,  57,  75],
#        [  5,  99,  69,  54,  78],
#        [  6,  94,  68,  49,  72],
#        [  7, 107,  84,  69,  82],
#        [  8, 107,  82,  61,  74],
#        [  9, 103,  78,  60,  76],
#        [ 10, 107,  80,  59,  73]])

# %%
df = pd.DataFrame(Compiled_Table.transpose(), columns=['Trial', 'Participant', 'Positives', 'True Positives' , 'Percent Correct'])
Trial_Table = df.style.hide().to_latex(column_format="c|c|c|c|c",hrules=False)

# %%
print(Trial_Table)
# Out:
# \begin{tabular}{c|c|c|c|c}
# Trial & Participant & Positives & True Positives & Percent Correct \\
# 1 & 103 & 79 & 61 & 77 \\
# 2 & 98 & 71 & 59 & 83 \\
# 3 & 108 & 83 & 59 & 71 \\
# 4 & 101 & 76 & 57 & 75 \\
# 5 & 99 & 69 & 54 & 78 \\
# 6 & 94 & 68 & 49 & 72 \\
# 7 & 107 & 84 & 69 & 82 \\
# 8 & 107 & 82 & 61 & 74 \\
# 9 & 103 & 78 & 60 & 76 \\
# 10 & 107 & 80 & 59 & 73 \\
# \end{tabular}

# %%
with open("../input_files/trial_table.tex", "w", encoding="utf-8") as f:
    f.writelines(Trial_Table)

# %%
Keep_Rolling = True
while Keep_Rolling:
    roll = dice_roll(10,12,1)
    cnt = np.count_nonzero(roll<2)
    if cnt == 0:
        Keep_Rolling = False
print(roll,cnt)
# Out:
# [[11  6  5 10  9  9  2  5 12  8]] 0

# %%
f.close()

# %%
math.comb(52,5)
# Out:
# 2598960

# %%
math.factorial(13)
# Out:
# 6227020800

# %%
hand = "smallstraight"

# %%
counts = {char: hand.count(char) for char in set(hand)}
print(counts)
# Out:
# {'i': 1, 'l': 2, 'a': 2, 'h': 1, 'm': 1, 's': 2, 'g': 1, 'r': 1, 't': 2}

# %%
n=len(hand)
product = 1
for key in counts:
    product *= math.comb(n,counts[key])
    n = n-counts[key]
print(product)
# Out:
# 389188800

# %%
len(hand)
# Out:
# 13

# %%
math.comb(13,2)*math.comb(11,2)*math.comb(9,2)*math.comb(7,2)*5*4*3*2*1
# Out:
# 389188800

# %%
math.comb(52,5) - math.comb(13,2)*math.comb(13,3)
# Out:
# 2576652

# %%
math.comb(13,2)*math.comb(13,3)
# Out:
# 22308
